# %% [markdown]
# ## Data Cleaning - HOTEL 1

# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd
import plotly.express as px
import numpy as np
import datetime

# %% [markdown]
# ## Import the data

# %% [markdown]
# ### 11 tables of Hotel_1

# %% [markdown]
# #### 1 - Upsell tábla
# - 83 sor
# - adattípusok OK
# - nincs NaN,
# - gond: EUR és HUF összegek egy oszlopban vannak
# - gond: vannak teljesen egyforma sorok, de ez életszerű, kérhetett ugyanaz a foglalás többször ugyanolyan szolgáltatást pl 71, 72, 73. sorok

# %%
upsell = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data/upsell_data_hotel_1.csv', sep=';')
upsell.head(3)
# Out:
#    search_log_id  upsell_type        name  unit_price  pieces  sum_price
# 0         112857            7     ROSE_HU      3500.0       1     3500.0
# 1         114033           10  NONABAR_HU      4800.0       1     4800.0
# 2         114367            6   FRUITS_HU      3500.0       1     3500.0

# %%
upsell[upsell['search_log_id'] == 112758]
# Out:
# Empty DataFrame
# Columns: [search_log_id, upsell_type, name, unit_price, pieces, sum_price]
# Index: []

# %%
upsell.describe()
# Out:
#        search_log_id  upsell_type    unit_price     pieces     sum_price
# count      83.000000    83.000000     83.000000  83.000000     83.000000
# mean   130854.590361    10.180723   5837.964940   1.265060   7770.180361
# std      9769.080974     7.293740   3817.431666   0.495943   6998.472509
# min    112857.000000     1.000000      9.700000   1.000000      9.700000
# 25%    120948.500000     5.000000   3500.000000   1.000000   3500.000000
# 50%    131444.000000     9.000000   5950.000000   1.000000   6000.000000
# 75%    138516.000000    16.000000   8350.000000   1.000000   9450.000000
# max    146067.000000    37.000000  14200.000000   3.000000  26400.000000

# %%
upsell['name'].count()
# Out:
# 83

# %%
upsell.groupby('name').count().head(3)
# Out:
#                search_log_id  upsell_type  unit_price  pieces  sum_price
# name
# CAKE_HU                    8            8           8       8          8
# CAPPUCCINO_DE              5            5           5       5          5
# CAPPUCCINO_HU              2            2           2       2          2

# %%
#54 db foglaláshoz tartozik a 83 sor, a search_log_id itt nem egyedi azonosító
len(upsell['search_log_id'].unique())
# Out:
# 54

# %%
#no duplicated rows
upsell[upsell.duplicated()]
# Out:
#     search_log_id  upsell_type       name  unit_price  pieces  sum_price
# 30         129168            1  DAYSPA_DE        23.2       2       46.4
# 72         141565            1  DAYSPA_HU      8350.0       1     8350.0
# 73         141565            1  DAYSPA_HU      8350.0       1     8350.0

# %%
upsell.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/upsell_hotel_1.csv')

# %% [markdown]
# #### 2 - Booking_data
# -802 sor
# - adattípusok rendben
# - gond: EUR és HUF összegek egy oszlopban vannak

# %%
booking = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data//booking_data_hotel_1.csv', sep=';')

# %%
booking.head(3)
# Out:
#    search_log_id  total_price_final  rooms_total_price  upsell_total_price  \
# 0         112857           99683.00          119952.22              3500.0
# 1         112906          302444.00          377114.44                 0.0
# 2         113050             622.43             793.16                 0.0
#
#    vouchers_total_price  loyalty_discount_total  redeemed_loyalty_points_total
# 0                     0                11995.22                        11774.0
# 1                     0                37711.44                        36959.0
# 2                     0                  118.97                            0.0

# %%
booking[booking['search_log_id'] == 112645]
# Out:
# Empty DataFrame
# Columns: [search_log_id, total_price_final, rooms_total_price, upsell_total_price, vouchers_total_price, loyalty_discount_total, redeemed_loyalty_points_total]
# Index: []

# %%
booking.describe()
# Out:
#        search_log_id  total_price_final  rooms_total_price  \
# count     802.000000       8.020000e+02       8.020000e+02
# mean   131071.062344       1.582970e+05       1.804741e+05
# std      9462.501514       1.421132e+05       1.572468e+05
# min    112857.000000       1.776800e+02       1.836000e+02
# 25%    123174.500000       7.497500e+04       8.870444e+04
# 50%    133948.000000       1.375850e+05       1.575972e+05
# 75%    138939.250000       2.233800e+05       2.514491e+05
# max    146108.000000       1.192546e+06       1.281987e+06
#
#        upsell_total_price  vouchers_total_price  loyalty_discount_total  \
# count          802.000000            802.000000              802.000000
# mean           804.145848            249.376559            17362.110224
# std           4056.736084           4990.643516            17952.527053
# min              0.000000              0.000000                0.000000
# ...

# %%
#no duplicated rows
booking[booking.duplicated()]
# Out:
# Empty DataFrame
# Columns: [search_log_id, total_price_final, rooms_total_price, upsell_total_price, vouchers_total_price, loyalty_discount_total, redeemed_loyalty_points_total]
# Index: []

# %%
len(booking['search_log_id'].unique())
# Out:
# 802

# %%
booking.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/booking_hotel_1.csv')

# %% [markdown]
# #### 3 - Child tábla (search_log_room_child)
# - 14025 sor
# -  adattípusok OK
# -  nincs NaN

# %%
child = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data//search_log_room_child_hotel_1.csv', sep=';')

# %%
child.head(3)
# Out:
#      id  search_log_room_id  age  baby_bed
# 0  1938                5797    3         0
# 1  1939                5915   13         0
# 2  1940                5915   10         0

# %%
len(child)
# Out:
# 14025

# %%
#no duplicated rows
child[child.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, search_log_room_id, age, baby_bed]
# Index: []

# %%
len(child['search_log_room_id'].unique())
# Out:
# 8685

# %%
len(child['id'].unique())
# Out:
# 14025

# %%
child.describe()
# Out:
#                  id  search_log_room_id           age      baby_bed
# count  14025.000000        14025.000000  14025.000000  14025.000000
# mean    9170.879643        24382.591373      8.301390      0.055258
# std     4185.930445        10633.570277      4.210544      0.228492
# min     1938.000000         5797.000000      0.000000      0.000000
# 25%     5557.000000        14853.000000      5.000000      0.000000
# 50%     9143.000000        25047.000000      8.000000      0.000000
# 75%    12798.000000        33698.000000     11.000000      0.000000
# max    16466.000000        42660.000000     17.000000      1.000000

# %%
child.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/child_hotel_1.csv')

# %% [markdown]
# #### 4 - SEARCH tábla (search_log_hotel)
# - 20.987 sor
# - nincs NaN
# - gond az EUR/HUF, de itt van dátum oszlop is, ide lehetne behozni az árfolyamokat először
# - adattisztitás:
# - dátumból: csak év-hónap-nap legyen
# - conversion oszlop: NaN értékeknek -1 érték (szűréshez kell)
# - total_price_final: NaN értékek nulla érték
# - új oszlop: total_price_HUF !!!

# %%
search = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data/search_log_hotel_1.csv', sep=';')

# %%
len(search)
# Out:
# 20987

# %%
len(search['search_log_session_id'].unique())
# Out:
# 11887

# %%
search.head(4)
# Out:
#        id  search_log_session_id         utc_datetime lang_code currency  \
# 0  112645                   4034  2024-09-17 22:19:09        hu      HUF
# 1  112648                   4037  2024-09-17 22:20:15        hu      HUF
# 2  112680                   4069  2024-09-17 22:27:13        de      EUR
# 3  112682                   4034  2024-09-17 22:28:30        hu      HUF
#
#       arrival   departure  days  nights  adults  children  conversion  \
# 0  2024-10-21  2024-10-25     5       4       2         0         NaN
# 1  2024-12-19  2024-12-22     4       3       2         1         NaN
# 2  2024-09-18  2024-09-20     3       2       2         0         NaN
# 3  2024-10-21  2024-10-25     5       4       4         0         NaN
#
#    total_price_final
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN

# %%
search.sort_values(by='search_log_session_id').head(30)
# Out:
#         id  search_log_session_id         utc_datetime lang_code currency  \
# 0   112645                   4034  2024-09-17 22:19:09        hu      HUF
# 3   112682                   4034  2024-09-17 22:28:30        hu      HUF
# 1   112648                   4037  2024-09-17 22:20:15        hu      HUF
# 2   112680                   4069  2024-09-17 22:27:13        de      EUR
# 4   112714                   4102  2024-09-17 22:38:42        en      EUR
# 5   112757                   4145  2024-09-17 23:16:47        hu      HUF
# 6   112758                   4145  2024-09-17 23:17:31        hu      HUF
# 7   112759                   4146  2024-09-18 01:27:28        hu      HUF
# 8   112760                   4147  2024-09-18 01:53:05        hu      HUF
# 9   112761                   4147  2024-09-18 01:59:34        hu      HUF
# 10  112762                   4148  2024-09-18 02:10:58        hu      HUF
# 11  112764                   4150  2024-09-18 03:46:37        de      EUR
# ...

# %%
search.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20987 entries, 0 to 20986
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     20987 non-null  int64
#  1   search_log_session_id  20987 non-null  int64
#  2   utc_datetime           20987 non-null  object
#  3   lang_code              20987 non-null  object
#  4   currency               20987 non-null  object
#  5   arrival                20987 non-null  object
#  6   departure              20987 non-null  object
#  7   days                   20987 non-null  int64
#  8   nights                 20987 non-null  int64
#  9   adults                 20987 non-null  int64
#  10  children               20987 non-null  int64
#  11  conversion             802 non-null    float64
#  12  total_price_final      802 non-null    float64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 2.1+ MB

# %%
#datatype change to date:
search['utc_datetime'] = pd.to_datetime(search['utc_datetime'])
search['arrival'] = pd.to_datetime(search['arrival'])
search['departure'] = pd.to_datetime(search['departure'])

# %%
#utc_datetime change to only year-month-day into a new column
search['utc_date'] = search['utc_datetime'].dt.strftime('%Y-%m-%d')

# %%
search.isna().sum()
# Out:
# id                           0
# search_log_session_id        0
# utc_datetime                 0
# lang_code                    0
# currency                     0
# arrival                      0
# departure                    0
# days                         0
# nights                       0
# adults                       0
# children                     0
# conversion               20185
# total_price_final        20185
# utc_date                     0
# dtype: int64

# %%
#Number of final bookings
20987-20185
# Out:
# 802

# %%
#conversion column: replace NaN with -1
search['conversion'].fillna(-1, inplace = True)

# %%
#final_price column: replace NaN with 0
search['total_price_final'].fillna(0, inplace = True)

# %%
search.head()
# Out:
#        id  search_log_session_id        utc_datetime lang_code currency  \
# 0  112645                   4034 2024-09-17 22:19:09        hu      HUF
# 1  112648                   4037 2024-09-17 22:20:15        hu      HUF
# 2  112680                   4069 2024-09-17 22:27:13        de      EUR
# 3  112682                   4034 2024-09-17 22:28:30        hu      HUF
# 4  112714                   4102 2024-09-17 22:38:42        en      EUR
#
#      arrival  departure  days  nights  adults  children  conversion  \
# 0 2024-10-21 2024-10-25     5       4       2         0        -1.0
# 1 2024-12-19 2024-12-22     4       3       2         1        -1.0
# 2 2024-09-18 2024-09-20     3       2       2         0        -1.0
# 3 2024-10-21 2024-10-25     5       4       4         0        -1.0
# 4 2024-09-25 2024-09-28     4       3       2         0        -1.0
#
#    total_price_final    utc_date
# 0                0.0  2024-09-17
# 1                0.0  2024-09-17
# ...

# %%
#no duplicated rows
search[search.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, search_log_session_id, utc_datetime, lang_code, currency, arrival, departure, days, nights, adults, children, conversion, total_price_final, utc_date]
# Index: []

# %%
search.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/search_hotel_1.csv')

# %% [markdown]
# #### 5 - Room details (search_log_room_hotel)
# - 23908 sor
# - adattípusok OK
# - van 22919 db NaN a picked_price, és picked_room oszlopban, ezek azért vannak mert nem választott már szobát a keresés során?
# - ami nem NaN, az kód a picked_room oszlopban, legyen 0 a NaN helyett?
# - ami nem NaN, az ár: HUF/EUR?, legyen 0 a NaN helyett?

# %%
room = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data/search_log_room_hotel_1.csv', sep=';')

# %%
room.head(15)
# Out:
#       id  search_log_id  adults  children  picked_price picked_room
# 0   5794         112645       2         0           NaN         NaN
# 1   5797         112648       2         1           NaN         NaN
# 2   5829         112680       2         0           NaN         NaN
# 3   5831         112682       4         0           NaN         NaN
# 4   5863         112714       2         0           NaN         NaN
# 5   5906         112757       2         0           NaN         NaN
# 6   5907         112758       2         0           NaN         NaN
# 7   5908         112759       2         0           NaN         NaN
# 8   5909         112760       2         0           NaN         NaN
# 9   5910         112761       2         0           NaN         NaN
# 10  5911         112762       2         0           NaN         NaN
# 11  5913         112764       2         0           NaN         NaN
# 12  5914         112765       2         0           NaN         NaN
# ...

# %%
len(room)
# Out:
# 23908

# %%
len(room['search_log_id'].unique())
# Out:
# 20987

# %%
room.isna().sum()
# Out:
# id                   0
# search_log_id        0
# adults               0
# children             0
# picked_price     22919
# picked_room      22919
# dtype: int64

# %%
23908-22919
# Out:
# 989

# %%
#no duplicated rows
room[room.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, search_log_id, adults, children, picked_price, picked_room]
# Index: []

# %%
room.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/room_hotel_1.csv')

# %% [markdown]
# #### 6 -   ROOM_OFFER
#
# - 109.938 sor
# -  adattípusok OK
# -  room price min and max can be equal!
# - room price: EUR/HUF keveredik

# %%
room_offer = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data/search_log_room_offer_hotel_1.csv', sep=";")

# %%
room_offer[room_offer['search_log_id'] == 112680]
# Out:
#       id  search_log_id  search_log_room_id room_code  room_price_min  \
# 6  15628         112680                5829    ROOMEE          465.60
# 7  15629         112680                5829    ROOMFF          504.40
# 8  15630         112680                5829    ROOMGG          516.04
#
#    room_price_max
# 6          465.60
# 7          504.40
# 8          516.04

# %%
room_offer.tail(3)
# Out:
#             id  search_log_id  search_log_room_id room_code  room_price_min  \
# 109935  195320         146420               42663    ROOMEE          697.00
# 109936  195321         146420               42663    ROOMFF          748.00
# 109937  195322         146420               42663    ROOMHH          811.75
#
#         room_price_max
# 109935          783.94
# 109936          834.94
# 109937          898.69

# %%
len(room_offer)
# Out:
# 109938

# %%
len(room_offer['id'].unique())
# Out:
# 109938

# %%
len(room_offer['search_log_id'].unique())
# Out:
# 18528

# %%
len(room_offer['search_log_room_id'].unique())
# Out:
# 20944

# %%
room_offer.isna().sum()
# Out:
# id                    0
# search_log_id         0
# search_log_room_id    0
# room_code             0
# room_price_min        0
# room_price_max        0
# dtype: int64

# %%
#no duplicated rows
room_offer[room_offer.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, search_log_id, search_log_room_id, room_code, room_price_min, room_price_max]
# Index: []

# %%
room_offer.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/room_offer_hotel_1.csv')

# %% [markdown]
# #### 7 -  Session
# - 11887 sor
# - üres sorok a utm-es oszlopokban, amik nem fontosak a Morgens szerint

# %%
session = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data/search_log_session_hotel_1.csv', sep=";")

# %%
session.head(50)
# Out:
#       id                                  uuid  session_id      utm_source  \
# 0   4034                 1145549807.1726611234  1726611549             NaN
# 1   4037                 2039466988.1726611511  1726611615        facebook
# 2   4069                 1556994523.1726611965  1726612033          google
# 3   4102                  901475575.1726612653  1726612722          google
# 4   4145                  408000469.1726614788  1726615007             NaN
# 5   4146                 1097283936.1726622460  1726622848             NaN
# 6   4147                 2046757301.1726624293  1726624385        facebook
# 7   4148                  261439511.1726615929  1726625458  l.facebook.com
# 8   4150                 1877848240.1715013016  1726631197             NaN
# 9   4151                  369265528.1726631243  1726631350             NaN
# 10  4153                 1386321193.1726632616  1726632681        (direct)
# ...

# %%
session.isna().sum()
# Out:
# id                 0
# uuid               0
# session_id         0
# utm_source       697
# utm_medium       697
# utm_campaign    1555
# dtype: int64

# %%
len(session['session_id'].unique())
# Out:
# 11682

# %%
session.groupby('session_id').count()
# Out:
#             id  uuid  utm_source  utm_medium  utm_campaign
# session_id
# 1726611549   1     1           0           0             1
# 1726611615   1     1           1           1             1
# 1726612033   1     1           1           1             0
# 1726612722   1     1           1           1             0
# 1726615007   1     1           0           0             1
# ...         ..   ...         ...         ...           ...
# 1729284680   1     1           1           1             0
# 1729285077   1     1           1           1             1
# 1729286582   1     1           1           1             1
# 1729286949   1     1           1           1             1
# 1729287722   1     1           1           1             1
#
# [11682 rows x 5 columns]

# %%
session.groupby('utm_source').count().sort_values(by='id', ascending=False)
# Out:
#                                 id  uuid  session_id  utm_medium  utm_campaign
# utm_source
# google                        7861  7861        7861        7861          6306
# (direct)                      1486  1486        1486        1486          1486
# facebook                       778   778         778         778           778
# bing                           268   268         268         268           268
# l.facebook.com                 129   129         129         129           129
# m.facebook.com                  98    98          98          98            98
# redir.d-edgeconnect.media       82    82          82          82            82
# ajanlat                         71    71          71          71            71
# source_1                        69    69          69          69            69
# ntp.msn.com                     55    55          55          55            55
# seznam                          40    40          40          40            40
# ...

# %%
session.groupby('utm_medium').count()
# Out:
#               id  uuid  session_id  utm_source  utm_campaign
# utm_medium
# (none)      1486  1486        1486        1486          1486
# cpc         7093  7093        7093        7093          5538
# ct            29    29          29          29            29
# email         35    35          35          35            35
# offline       58    58          58          58            58
# organic     1875  1875        1875        1875          1875
# paid           1     1           1           1             1
# referral     613   613         613         613           613

# %%
session.groupby('utm_medium').count()
# Out:
#               id  uuid  session_id  utm_source  utm_campaign
# utm_medium
# (none)      1486  1486        1486        1486          1486
# cpc         7093  7093        7093        7093          5538
# ct            29    29          29          29            29
# email         35    35          35          35            35
# offline       58    58          58          58            58
# organic     1875  1875        1875        1875          1875
# paid           1     1           1           1             1
# referral     613   613         613         613           613

# %%
#no duplicated rows
session[session.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, uuid, session_id, utm_source, utm_medium, utm_campaign]
# Index: []

# %%
session.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/session_hotel_1.csv')

# %% [markdown]
# #### 8 -  DAILY_USERS
# - 1923 sor
# - date oszlop: adattípus változtatás

# %%
daily_users = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data/website_daily_users_hotel_1.csv', sep=";")

# %%
daily_users.head(30)
# Out:
#           date                   utm_source_and_medium       utm_campaign  \
# 0   2024-09-18                               (not set)          (not set)
# 1   2024-09-18                       (direct) / (none)           (direct)
# 2   2024-09-18                            google / cpc          (not set)
# 3   2024-09-18                        google / organic          (organic)
# 4   2024-09-18                          facebook / cpc        campaign_14
# 5   2024-09-18                            google / cpc           hu_brand
# 6   2024-09-18                            google / cpc        campaign_15
# 7   2024-09-18                            google / cpc        campaign_16
# 8   2024-09-18                            google / cpc        campaign_17
# 9   2024-09-18                            google / cpc      hu_pmax_brand
# 10  2024-09-18                          facebook / cpc        campaign_18
# 11  2024-09-18               l.facebook.com / referral         (referral)
# ...

# %%
daily_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1923 entries, 0 to 1922
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1923 non-null   object
#  1   utm_source_and_medium  1923 non-null   object
#  2   utm_campaign           1923 non-null   object
#  3   user_count             1923 non-null   int64
#  4   session_count          1923 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 75.2+ KB

# %%
#datatype change to date
daily_users['date'] = pd.to_datetime(daily_users['date'])

# %%
daily_users.isna().sum()
# Out:
# date                     0
# utm_source_and_medium    0
# utm_campaign             0
# user_count               0
# session_count            0
# dtype: int64

# %%
#no duplicated rows
daily_users[daily_users.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, utm_source_and_medium, utm_campaign, user_count, session_count]
# Index: []

# %%
daily_users.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/daily_users_hotel_1.csv')

# %% [markdown]
# #### 9 -  BUDGET
# - 31 sor
# - első oszlopot átnevezni
# - adattípus változtatás

# %%
budget = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data/daily_ppc_budget_hotel_1.csv', sep=",")

# %%
budget.head()
# Out:
#     Unnamed: 0  daily_google_spend  daily_microsoft_spend  daily_meta_spend
# 0  2024.09.18.              128044                  10564             35950
# 1  2024.09.19.              137322                  12048             53112
# 2  2024.09.20.              124825                   8484             61717
# 3  2024.09.21.              106588                   6976             64140
# 4  2024.09.22.              144448                   6684             73310

# %%
#Rename the first column
budget.rename(columns = {'Unnamed: 0':'date'}, inplace = True)

# %%
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   31 non-null     object
#  1   daily_google_spend     31 non-null     int64
#  2   daily_microsoft_spend  31 non-null     int64
#  3   daily_meta_spend       31 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.1+ KB

# %%
#change date type:
budget['date'] = pd.to_datetime(budget['date'])

# %%
budget.isna().sum()
# Out:
# date                     0
# daily_google_spend       0
# daily_microsoft_spend    0
# daily_meta_spend         0
# dtype: int64

# %%
#no duplicated rows
budget[budget.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, daily_google_spend, daily_microsoft_spend, daily_meta_spend]
# Index: []

# %%
budget.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/budget_hotel_1.csv')

# %% [markdown]
# #### 10 -  DATEPICKERS
# - 1158 sor
# - date oszlop adatmódosítás

# %%
datepickers = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data/datepicker_daily_visitors_hotel_1.csv', sep=";")

# %%
datepickers.head()
# Out:
#          date utm_source_and_medium utm_campaign  user_count  session_count
# 0  2024-09-18     (direct) / (none)     (direct)         104            124
# 1  2024-09-18          google / cpc    (not set)          59             59
# 2  2024-09-18      google / organic    (organic)          37             40
# 3  2024-09-18          google / cpc     hu_brand          30             34
# 4  2024-09-18          google / cpc  campaign_16          23             25

# %%
len(datepickers)
# Out:
# 1158

# %%
len(datepickers['date'].unique())
# Out:
# 31

# %%
len(datepickers['utm_source_and_medium'].unique())
# Out:
# 68

# %%
len(datepickers['utm_campaign'].unique())
# Out:
# 56

# %%
datepickers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158 entries, 0 to 1157
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1158 non-null   object
#  1   utm_source_and_medium  1158 non-null   object
#  2   utm_campaign           1158 non-null   object
#  3   user_count             1158 non-null   int64
#  4   session_count          1158 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 45.4+ KB

# %%
datepickers['date'] = pd.to_datetime(datepickers['date'])

# %%
datepickers.isna().sum()
# Out:
# date                     0
# utm_source_and_medium    0
# utm_campaign             0
# user_count               0
# session_count            0
# dtype: int64

# %%
#no duplicated rows
datepickers[datepickers.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, utm_source_and_medium, utm_campaign, user_count, session_count]
# Index: []

# %%
datepickers.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/datepickers_hotel_1.csv')

# %% [markdown]
# #### 11 - OCCUPANCY
# - 10788 dor, mert 31 napon át nézzük (x) a 348 napos időszakot
# - két dátum oszlopnál adattípus módosítás

# %%
occupancy = pd.read_csv('./../Morgens_notebooks/HOTEL_1/Original_data/daily_occupancy_hotel_1.csv', sep=";")

# %%
occupancy
# Out:
#       recording_date subject_date  fill_rate
# 0         2024-09-18   2024-09-18     67.368
# 1         2024-09-18   2024-09-19     65.789
# 2         2024-09-18   2024-09-20     67.895
# 3         2024-09-18   2024-09-21     59.474
# 4         2024-09-18   2024-09-22     43.684
# ...              ...          ...        ...
# 10783     2024-10-18   2025-08-27      0.526
# 10784     2024-10-18   2025-08-28      0.526
# 10785     2024-10-18   2025-08-29      0.526
# 10786     2024-10-18   2025-08-30      0.526
# 10787     2024-10-18   2025-08-31      0.526
#
# [10788 rows x 3 columns]

# %%
occupancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10788 entries, 0 to 10787
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   recording_date  10788 non-null  object
#  1   subject_date    10788 non-null  object
#  2   fill_rate       10788 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 253.0+ KB

# %%
occupancy['recording_date'] = pd.to_datetime(occupancy['recording_date'])
occupancy['subject_date'] = pd.to_datetime(occupancy['subject_date'])

# %%
occupancy.isna().sum()
# Out:
# recording_date    0
# subject_date      0
# fill_rate         0
# dtype: int64

# %%
#no duplicated rows
occupancy[occupancy.duplicated()]
# Out:
# Empty DataFrame
# Columns: [recording_date, subject_date, fill_rate]
# Index: []

# %%
occupancy.to_csv('./../Morgens_notebooks/HOTEL_1/Clean_data/occupancy_hotel_1.csv')
